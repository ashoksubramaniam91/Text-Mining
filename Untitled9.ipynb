# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import nltk

# %%
review=pd.read_csv('C:\\Users\\Ashok\\Desktop\\GL\\Text_Mining\\Topic modelling\\amazon_reviews.csv')

# %%
review.head()
# Out:
#          asin  overall                                         reviewText  \
# 0  B000HDJXNA        1  What I recieved is not what is pictured here O...
# 1  B006KKS7XQ        5  Excellent unit and a pretty simple install usi...
# 2  B002NP8XJ0        5  I'm enjoying this keyboard, I'm getting anothe...
# 3  B000EITTLE        4  Overall, this is a fantastic camera that I'm e...
# 4  B006CRXK4S        5  These work very well with mySamsung PN64D7000 ...
#
#     reviewTime      reviewerID                   reviewerName  \
# 0  12 26, 2012  A29YXBFTD7QUP3                            HHA
# 1  09 20, 2013  A3IMTXFYD7CGDN  Peter W. George "soyflakeman"
# 2  08 31, 2010   AXNOW20FQKHVW                     B. Hayashi
# 3   02 3, 2008  A10KCAK279LO0W         mmcwatters "macdadi80"
# 4  01 28, 2012  A19XXLMZXR764J                   S. Garfinkle
#
#                                              summary  unixReviewTime
# 0                                      Buyer be ware    1.356480e+09
# 1                    high quality without high price    1.379635e+09
# 2  Superb keyboard + solution for slow wake up an...    1.283213e+09
# 3                  One qualm: not great in low light    1.201997e+09
# 4                               Work great, fit well    1.327709e+09

# %%
review = review.dropna()

# %%
reviews = review[['reviewText']]
reviews = reviews.reset_index(drop=True) 
print(reviews.head())
for i in range(5):
    print("Review #",i+1)
    print(reviews.reviewText[i])
    #print(review.Text[i])
    print()
# Out:
#                                           reviewText
# 0  What I recieved is not what is pictured here O...
# 1  Excellent unit and a pretty simple install usi...
# 2  I'm enjoying this keyboard, I'm getting anothe...
# 3  Overall, this is a fantastic camera that I'm e...
# 4  These work very well with mySamsung PN64D7000 ...
# Review # 1
# What I recieved is not what is pictured here OR ADVERTIZED, but it is a vidio cable, and it does do the job I needed it for. If you were looking for a high quality cable do not buy this product. I recieved a cheap thin flimsy cable that is not gold plated or anything else they claim here. Bait and Switch? or a mistake in the order !!!!! . I do not know. I will attempt to contact the sender and find out. I contacted the seller and they told me to contact amazon.com so i did, and amazon.com was good enough to give me a $4.00 refund; which is good, because all this cable is woth is $2 to $3. I only needed it to run my wife's kareokee to the TV. If it was for any thing else I would have sent it back for a full refund. I'm surprised that this item is still listed as a high grade cable.
#
# Review # 2
# Excellent unit and a pretty simple install using the wiring adapter and removal tools I purchased with it. Kenwood quality is evident in the look and sound today and bodes well for the future. If you get the extra stuff its really simple to install--just be sure you have the frame on correctly (I 'd use a sharpie and mark it 'top' and 'front' before you slide it off the radio to bend the tabs out so it will fit snugly in the dash). This one went in my wife's 99 Miata and I'll likely do another in mine because it will be even simpler the next time. She also reports that the CD player is pretty skip-free, which isn't easy in a sports car.
#
# Review # 3
# I'm enjoying this keyboard, I'm getting another one for my other laptop that I keep at home.I've had this now for almost a year. Yes, I experience the BT lag, too, but I live with it. (Hence the 4 stars instead of 5) ***UPDATE*** (Now 5 stars--see update below.) Would I buy it again? Well, yes...as I said, I'm buying another. One BT annoyance is that you can pair your device with only one other device.Great layout, excellent size, superb tactile feel. One big advantage with a wireless keyboard and using a note/netbook is that you are no longer at the mercy of how high the desk/table/airline tray is--you can have the comfort (and more healthy) height of typing from your lap. I love it!I love the slim design and the power off button--it fits great in my laptop backpack. It is so light, too. With my 2.8 lbs. Asus netbook, adding this lightweight is really nothing. And because of its size, it fits in any bag, attach&eacute;, backpack, etc. easily.***UPDATE***Been using my two MS Mobile 6000's for a year now. Still loving it. Also--I am using it on my iPod Touch! I no longer am taking my netbook or my laptop to school. Just this keyboard and my Touch. Can't beat that.I came across a post that helped me solve any BT wake up issues. Instead of 20 seconds or so of waiting, it only takes about 2 seconds to wake up. Also, since replacing my laptop, I was experiencing seriously annoying disconnections, sometimes requiring deleting it from BT and reinstalling it. This blog post solved it all. In my case, all I needed to do was to clear the checkbox "Allow the computer to turn off this device to save power" in Device Manager and NO MORE PROBLEMS!!! Here's the link:[...]Enjoy!
#
# Review # 4
# Overall, this is a fantastic camera that I'm extremely pleased with.However, I bought it to take pictures indoors without flash. I was prepared for lower quality images indoors without a flash, but the Lumix does not do nearly as well as my Canon Elph in identical lighting situations. The flash is good, but if you want a camera to shoot indoors without flash, be prepared for fairly noisy images with a lot of artifacts.
#
# Review # 5
# These work very well with mySamsung PN64D7000 64-Inch 1080p 600 Hz 3D Plasma HDTV (Black). They come in a nice felt bag inside a zipped hard case. They fit very well even over my glasses (which are 58 mm from side to side FWIW). They charge via a microsub cable (included, in case you don't already have a bunch). I like them more than my Samsung SSG-3050s. I'll buy more of these. One tip -- they don't seem to auto-associate the first time you turn them on. So, first fully charge them, then turn on your TV, then press and hold the power button until it blinks rapidly. Then it will associate and work great.

# %%
contractions = {"ain't": "am not","aren't": "are not","can't": "cannot","can't've": "cannot have","'cause": "because","could've": "could have","couldn't": "could not","couldn't've": "could not have","didn't": "did not","doesn't": "does not","don't": "do not","hadn't": "had not","hadn't've": "had not have","hasn't": "has not","haven't": "have not","he'd": "he would","he'd've": "he would have"}

# %%
def clean_text(text, remove_stopwords=True):
    # Convert words to lower case
    text = text.lower()
    if True:
        text = text.split()
        new_text = []
        for word in text:
            if word in contractions:
                new_text.append(contractions[word])
            else:
                new_text.append(word)
                text = " ".join(new_text)
                text = re.sub(r'https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
                text = re.sub(r'\<a href', ' ', text)
                text = re.sub(r'&amp;', '', text)
                text = re.sub(r'[_"\-;%()|+&=*%.,!?:#$@\[\]/]', ' ', text)
                text = re.sub(r'<br />', ' ', text)
                text = re.sub(r'\'', ' ', text)
                if remove_stopwords:
                    text = text.split()
                    stops = set(stopwords.words("english"))
                    text = [w for w in text if not w in stops]
                    text = " ".join(text)
                return text

# %%
import nltk

def clean_sentence(doc,stopwords,stemmer):
    words = doc.split(' ')
    words_clean = [stemmer.stem(word) for word in words if word not in stopwords]
    return ' '.join(words_clean)
     

def clean_documents(docs_raw):
    stopwords = nltk.corpus.stopwords.words('english')
    stemmer = nltk.stem.PorterStemmer()
    docs = docs_raw.str.lower().str.replace('[^a-z ]','')
    docs_clean = docs.apply(lambda doc: clean_sentence(doc,stopwords,stemmer))
    return docs_clean

# %%
reviews1 = clean_documents(reviews['reviewText'])
reviews1.head()
# Out:
# 0    reciev pictur advert vidio cabl job need look ...
# 1    excel unit pretti simpl instal use wire adapt ...
# 2    im enjoy keyboard im get anoth one laptop keep...
# 3    overal fantast camera im extrem pleas withhowe...
# 4    work well mysamsung pnd inch p  hz plasma hdtv...
# Name: reviewText, dtype: object

# %%
reviews2 = clean_text(reviews['reviewText'])
reviews2.head()

# %%
# Clean the summaries and texts
import re
clean_summaries = []
for summary in reviews.reviewText:
    clean_summaries.append(clean_text(summary, remove_stopwords=False))
print("Summaries are complete.")
# Out:
# Summaries are complete.

# %%
from pickle import dump
stories = list()
for i, text in enumerate(clean_summaries):
    stories.append({'story': text, 'highlights': clean_summaries[i]})
    # save to file
dump(stories, open('C:\\Users\\Ashok\\Desktop\\GL\\Text_Mining\\Topic modelling\\review_dataset1.pkl','wb'))

# %%
batch_size = 64
epochs = 110
latent_dim = 256
num_samples = 10000

# %%
import pickle
stories = pickle.load(open('C:\\Users\\Ashok\\Desktop\\GL\\Text_Mining\\Topic modelling\\review_dataset1.pkl', 'rb'))
print('Loaded Stories %d' % len(stories))
print(type(stories))
# Out:
# Loaded Stories 3805
# <class 'list'>

# %%
stories
# Out:
# [{'story': 'what', 'highlights': 'what'},
#  {'story': 'excellent', 'highlights': 'excellent'},
#  {'story': 'i m', 'highlights': 'i m'},
#  {'story': 'overall ', 'highlights': 'overall '},
#  {'story': 'these', 'highlights': 'these'},
#  {'story': 'its', 'highlights': 'its'},
#  {'story': 'a', 'highlights': 'a'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'very', 'highlights': 'very'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i ve', 'highlights': 'i ve'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'so', 'highlights': 'so'},
#  {'story': 'brought', 'highlights': 'brought'},
#  {'story': 'while', 'highlights': 'while'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'now', 'highlights': 'now'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'love', 'highlights': 'love'},
#  {'story': 'we', 'highlights': 'we'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'many', 'highlights': 'many'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'we', 'highlights': 'we'},
#  {'story': 'installed', 'highlights': 'installed'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'sounds', 'highlights': 'sounds'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'edit', 'highlights': 'edit'},
#  {'story': 'pros ', 'highlights': 'pros '},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'excellent', 'highlights': 'excellent'},
#  {'story': 'so', 'highlights': 'so'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'please', 'highlights': 'please'},
#  {'story': 'i ve', 'highlights': 'i ve'},
#  {'story': 'these', 'highlights': 'these'},
#  {'story': 'pros lightscribe', 'highlights': 'pros lightscribe'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'picked', 'highlights': 'picked'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'these', 'highlights': 'these'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'given', 'highlights': 'given'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'well ', 'highlights': 'well '},
#  {'story': 'first', 'highlights': 'first'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'so', 'highlights': 'so'},
#  {'story': 'switched', 'highlights': 'switched'},
#  {'story': 'while', 'highlights': 'while'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'ordered', 'highlights': 'ordered'},
#  {'story': 'if', 'highlights': 'if'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'these', 'highlights': 'these'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'if', 'highlights': 'if'},
#  {'story': 'item', 'highlights': 'item'},
#  {'story': 'my', 'highlights': 'my'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'opened', 'highlights': 'opened'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'sigma', 'highlights': 'sigma'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'screen', 'highlights': 'screen'},
#  {'story': 'i ve', 'highlights': 'i ve'},
#  {'story': 'believe', 'highlights': 'believe'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'super', 'highlights': 'super'},
#  {'story': 'omg ', 'highlights': 'omg '},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'my', 'highlights': 'my'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'cannot beat', 'highlights': 'cannot beat'},
#  {'story': 'one', 'highlights': 'one'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'love', 'highlights': 'love'},
#  {'story': 'worked', 'highlights': 'worked'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i ve', 'highlights': 'i ve'},
#  {'story': 'best', 'highlights': 'best'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'seller', 'highlights': 'seller'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'another', 'highlights': 'another'},
#  {'story': 'update', 'highlights': 'update'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'great', 'highlights': 'great'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'progreat', 'highlights': 'progreat'},
#  {'story': 'have', 'highlights': 'have'},
#  {'story': 'i m', 'highlights': 'i m'},
#  {'story': 'these', 'highlights': 'these'},
#  {'story': 'love', 'highlights': 'love'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'prosnice', 'highlights': 'prosnice'},
#  {'story': 'so', 'highlights': 'so'},
#  {'story': 'i ve', 'highlights': 'i ve'},
#  {'story': 'sandisk', 'highlights': 'sandisk'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'great', 'highlights': 'great'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'after', 'highlights': 'after'},
#  {'story': 'does', 'highlights': 'does'},
#  {'story': 'does', 'highlights': 'does'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'android', 'highlights': 'android'},
#  {'story': 'when', 'highlights': 'when'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'update', 'highlights': 'update'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'functional ', 'highlights': 'functional '},
#  {'story': 'just', 'highlights': 'just'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'fan', 'highlights': 'fan'},
#  {'story': 'building', 'highlights': 'building'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'if', 'highlights': 'if'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'was', 'highlights': 'was'},
#  {'story': 'same', 'highlights': 'same'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'case', 'highlights': 'case'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'if', 'highlights': 'if'},
#  {'story': 'i m', 'highlights': 'i m'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'so', 'highlights': 'so'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'as', 'highlights': 'as'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'if', 'highlights': 'if'},
#  {'story': 'perfect', 'highlights': 'perfect'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'simple ', 'highlights': 'simple '},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'great', 'highlights': 'great'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'there', 'highlights': 'there'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'have not used', 'highlights': 'have not used'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'it s', 'highlights': 'it s'},
#  {'story': 'i ve', 'highlights': 'i ve'},
#  {'story': 'these', 'highlights': 'these'},
#  {'story': 'just', 'highlights': 'just'},
#  {'story': 'no', 'highlights': 'no'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'fit', 'highlights': 'fit'},
#  {'story': 'these', 'highlights': 'these'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'these', 'highlights': 'these'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'as', 'highlights': 'as'},
#  {'story': 'not', 'highlights': 'not'},
#  {'story': 'my', 'highlights': 'my'},
#  {'story': 'beautiful', 'highlights': 'beautiful'},
#  {'story': 'very', 'highlights': 'very'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'great', 'highlights': 'great'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'surprisingly', 'highlights': 'surprisingly'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'we', 'highlights': 'we'},
#  {'story': 'very', 'highlights': 'very'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'could not be', 'highlights': 'could not be'},
#  {'story': 'really', 'highlights': 'really'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'my', 'highlights': 'my'},
#  {'story': 'i ve', 'highlights': 'i ve'},
#  {'story': 'yes', 'highlights': 'yes'},
#  {'story': 'there', 'highlights': 'there'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'when', 'highlights': 'when'},
#  {'story': 'it s', 'highlights': 'it s'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'nice', 'highlights': 'nice'},
#  {'story': 'i ve', 'highlights': 'i ve'},
#  {'story': 'for', 'highlights': 'for'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'let', 'highlights': 'let'},
#  {'story': 'at', 'highlights': 'at'},
#  {'story': 'just', 'highlights': 'just'},
#  {'story': 'since', 'highlights': 'since'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'nice', 'highlights': 'nice'},
#  {'story': 'my', 'highlights': 'my'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'great', 'highlights': 'great'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'with', 'highlights': 'with'},
#  {'story': 'just', 'highlights': 'just'},
#  {'story': 'on', 'highlights': 'on'},
#  {'story': 'product', 'highlights': 'product'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'well crafted ', 'highlights': 'well crafted '},
#  {'story': 'for', 'highlights': 'for'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'bought', 'highlights': 'bought'},
#  {'story': 'mine', 'highlights': 'mine'},
#  {'story': 'to', 'highlights': 'to'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'after', 'highlights': 'after'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'these', 'highlights': 'these'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'not', 'highlights': 'not'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'transmission', 'highlights': 'transmission'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'cannot hurt', 'highlights': 'cannot hurt'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'thanks', 'highlights': 'thanks'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i ve', 'highlights': 'i ve'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'as', 'highlights': 'as'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'own', 'highlights': 'own'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'its', 'highlights': 'its'},
#  {'story': 'i m', 'highlights': 'i m'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'does', 'highlights': 'does'},
#  {'story': 'before', 'highlights': 'before'},
#  {'story': 'just', 'highlights': 'just'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i m', 'highlights': 'i m'},
#  {'story': 'i ve', 'highlights': 'i ve'},
#  {'story': 'so', 'highlights': 'so'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': '   reflects', 'highlights': '   reflects'},
#  {'story': 'hard', 'highlights': 'hard'},
#  {'story': 'after', 'highlights': 'after'},
#  {'story': 'we', 'highlights': 'we'},
#  {'story': 'for', 'highlights': 'for'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'does', 'highlights': 'does'},
#  {'story': 'they', 'highlights': 'they'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'made', 'highlights': 'made'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'adapters', 'highlights': 'adapters'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'waste', 'highlights': 'waste'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'iteam', 'highlights': 'iteam'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'to', 'highlights': 'to'},
#  {'story': 'well ', 'highlights': 'well '},
#  {'story': 'sadly ', 'highlights': 'sadly '},
#  {'story': 'if', 'highlights': 'if'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'during', 'highlights': 'during'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'like', 'highlights': 'like'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'update', 'highlights': 'update'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'bought', 'highlights': 'bought'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'when', 'highlights': 'when'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'one', 'highlights': 'one'},
#  {'story': 'great', 'highlights': 'great'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'intended', 'highlights': 'intended'},
#  {'story': 'perfect', 'highlights': 'perfect'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'installed', 'highlights': 'installed'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'after', 'highlights': 'after'},
#  {'story': 'i ve', 'highlights': 'i ve'},
#  {'story': 'here s', 'highlights': 'here s'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'as', 'highlights': 'as'},
#  {'story': 'usb', 'highlights': 'usb'},
#  {'story': 'these', 'highlights': 'these'},
#  {'story': 'upgraded', 'highlights': 'upgraded'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'great', 'highlights': 'great'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i ve', 'highlights': 'i ve'},
#  {'story': 'great', 'highlights': 'great'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'well', 'highlights': 'well'},
#  {'story': 'husband', 'highlights': 'husband'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'these', 'highlights': 'these'},
#  {'story': 'reader', 'highlights': 'reader'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'looks', 'highlights': 'looks'},
#  {'story': 'bought', 'highlights': 'bought'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'nice', 'highlights': 'nice'},
#  {'story': 'very', 'highlights': 'very'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'like', 'highlights': 'like'},
#  {'story': 'these', 'highlights': 'these'},
#  {'story': 'was', 'highlights': 'was'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'they', 'highlights': 'they'},
#  {'story': 'love', 'highlights': 'love'},
#  {'story': 'decent', 'highlights': 'decent'},
#  {'story': 'western', 'highlights': 'western'},
#  {'story': 'blazing', 'highlights': 'blazing'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'great', 'highlights': 'great'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'upon', 'highlights': 'upon'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i ', 'highlights': 'i '},
#  {'story': 'could not get', 'highlights': 'could not get'},
#  {'story': '  62 enormous', 'highlights': '  62 enormous'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i m', 'highlights': 'i m'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'at', 'highlights': 'at'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'buying', 'highlights': 'buying'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'great', 'highlights': 'great'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'three', 'highlights': 'three'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i m', 'highlights': 'i m'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'screen', 'highlights': 'screen'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'nothing', 'highlights': 'nothing'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'in', 'highlights': 'in'},
#  {'story': 'class', 'highlights': 'class'},
#  {'story': 'scan', 'highlights': 'scan'},
#  {'story': 'very', 'highlights': 'very'},
#  {'story': 'great', 'highlights': 'great'},
#  {'story': 'good', 'highlights': 'good'},
#  {'story': 'this ', 'highlights': 'this '},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'great', 'highlights': 'great'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'in', 'highlights': 'in'},
#  {'story': 'i ve', 'highlights': 'i ve'},
#  {'story': 'monitor', 'highlights': 'monitor'},
#  {'story': 'mine', 'highlights': 'mine'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'always', 'highlights': 'always'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'owned', 'highlights': 'owned'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'a', 'highlights': 'a'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'my', 'highlights': 'my'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'folds', 'highlights': 'folds'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'just', 'highlights': 'just'},
#  {'story': 'my', 'highlights': 'my'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'just', 'highlights': 'just'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'bought', 'highlights': 'bought'},
#  {'story': 'about', 'highlights': 'about'},
#  {'story': 'if', 'highlights': 'if'},
#  {'story': 'bought', 'highlights': 'bought'},
#  {'story': 'not', 'highlights': 'not'},
#  {'story': 'amazon', 'highlights': 'amazon'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'not', 'highlights': 'not'},
#  {'story': 'great', 'highlights': 'great'},
#  {'story': 'first ', 'highlights': 'first '},
#  {'story': 'we', 'highlights': 'we'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'a', 'highlights': 'a'},
#  {'story': 'styluses', 'highlights': 'styluses'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'after', 'highlights': 'after'},
#  {'story': 'after', 'highlights': 'after'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'for', 'highlights': 'for'},
#  {'story': 'all', 'highlights': 'all'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'omg ', 'highlights': 'omg '},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'with', 'highlights': 'with'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'after', 'highlights': 'after'},
#  {'story': 'fairly', 'highlights': 'fairly'},
#  {'story': 'so', 'highlights': 'so'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'worked', 'highlights': 'worked'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'bought', 'highlights': 'bought'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'item', 'highlights': 'item'},
#  {'story': 'perfect', 'highlights': 'perfect'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'usage i m', 'highlights': 'usage i m'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'given', 'highlights': 'given'},
#  {'story': 'bought', 'highlights': 'bought'},
#  {'story': 'great', 'highlights': 'great'},
#  {'story': 'good', 'highlights': 'good'},
#  {'story': 'well ', 'highlights': 'well '},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'so', 'highlights': 'so'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'advertised', 'highlights': 'advertised'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'overall ', 'highlights': 'overall '},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'finally ', 'highlights': 'finally '},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'click', 'highlights': 'click'},
#  {'story': 'glasses', 'highlights': 'glasses'},
#  {'story': 'great', 'highlights': 'great'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'hi i ve', 'highlights': 'hi i ve'},
#  {'story': 'best', 'highlights': 'best'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i ve', 'highlights': 'i ve'},
#  {'story': 'what', 'highlights': 'what'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'not', 'highlights': 'not'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'thank', 'highlights': 'thank'},
#  {'story': 'i m', 'highlights': 'i m'},
#  {'story': 'had', 'highlights': 'had'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'my', 'highlights': 'my'},
#  {'story': 'what', 'highlights': 'what'},
#  {'story': 'how', 'highlights': 'how'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'in', 'highlights': 'in'},
#  {'story': 'when', 'highlights': 'when'},
#  {'story': 'with', 'highlights': 'with'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'all', 'highlights': 'all'},
#  {'story': 'i m', 'highlights': 'i m'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'crazy', 'highlights': 'crazy'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'while', 'highlights': 'while'},
#  {'story': 'just', 'highlights': 'just'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'these', 'highlights': 'these'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'extremely', 'highlights': 'extremely'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'all', 'highlights': 'all'},
#  {'story': 'i m', 'highlights': 'i m'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'full', 'highlights': 'full'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'ok', 'highlights': 'ok'},
#  {'story': 'no', 'highlights': 'no'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'just', 'highlights': 'just'},
#  {'story': 'nothing', 'highlights': 'nothing'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'although', 'highlights': 'although'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'lightweight ', 'highlights': 'lightweight '},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'not', 'highlights': 'not'},
#  {'story': 'includes', 'highlights': 'includes'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'got', 'highlights': 'got'},
#  {'story': 'nice', 'highlights': 'nice'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'blue', 'highlights': 'blue'},
#  {'story': 'first', 'highlights': 'first'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'seeing', 'highlights': 'seeing'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'here', 'highlights': 'here'},
#  {'story': 'these', 'highlights': 'these'},
#  {'story': 'usability', 'highlights': 'usability'},
#  {'story': 'oh ', 'highlights': 'oh '},
#  {'story': 'bought', 'highlights': 'bought'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'perfect', 'highlights': 'perfect'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'pros ', 'highlights': 'pros '},
#  {'story': 'brought', 'highlights': 'brought'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'perfect', 'highlights': 'perfect'},
#  {'story': 'great', 'highlights': 'great'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'pros ', 'highlights': 'pros '},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'canon', 'highlights': 'canon'},
#  {'story': 'i d', 'highlights': 'i d'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'here', 'highlights': 'here'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'love', 'highlights': 'love'},
#  {'story': 'chose', 'highlights': 'chose'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'does', 'highlights': 'does'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'what', 'highlights': 'what'},
#  {'story': 'let s', 'highlights': 'let s'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'after', 'highlights': 'after'},
#  {'story': 'simple', 'highlights': 'simple'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'just', 'highlights': 'just'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'high', 'highlights': 'high'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'yea ', 'highlights': 'yea '},
#  {'story': 'once', 'highlights': 'once'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'thought', 'highlights': 'thought'},
#  {'story': 'does', 'highlights': 'does'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'for', 'highlights': 'for'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'its', 'highlights': 'its'},
#  {'story': 'my', 'highlights': 'my'},
#  {'story': 'price', 'highlights': 'price'},
#  {'story': 'awesome ', 'highlights': 'awesome '},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'most', 'highlights': 'most'},
#  {'story': 'had', 'highlights': 'had'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'minor', 'highlights': 'minor'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'overall', 'highlights': 'overall'},
#  {'story': 'its', 'highlights': 'its'},
#  {'story': 'a', 'highlights': 'a'},
#  {'story': 'if', 'highlights': 'if'},
#  {'story': 'like', 'highlights': 'like'},
#  {'story': 'compact', 'highlights': 'compact'},
#  {'story': 'we', 'highlights': 'we'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i ve', 'highlights': 'i ve'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'so', 'highlights': 'so'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'what', 'highlights': 'what'},
#  {'story': 'very', 'highlights': 'very'},
#  {'story': 'solid', 'highlights': 'solid'},
#  {'story': 'using', 'highlights': 'using'},
#  {'story': 'bough', 'highlights': 'bough'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'check', 'highlights': 'check'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'easy', 'highlights': 'easy'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'of', 'highlights': 'of'},
#  {'story': 'use', 'highlights': 'use'},
#  {'story': 'bought', 'highlights': 'bought'},
#  {'story': 'bought', 'highlights': 'bought'},
#  {'story': 'bought', 'highlights': 'bought'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'sometimes', 'highlights': 'sometimes'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'bought', 'highlights': 'bought'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'looks', 'highlights': 'looks'},
#  {'story': 'i ve', 'highlights': 'i ve'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'highly', 'highlights': 'highly'},
#  {'story': 'used', 'highlights': 'used'},
#  {'story': 'she', 'highlights': 'she'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'so', 'highlights': 'so'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'for', 'highlights': 'for'},
#  {'story': 'you', 'highlights': 'you'},
#  {'story': 'who', 'highlights': 'who'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'my', 'highlights': 'my'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'excellent', 'highlights': 'excellent'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'never', 'highlights': 'never'},
#  {'story': 'short', 'highlights': 'short'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'there', 'highlights': 'there'},
#  {'story': 'cheap', 'highlights': 'cheap'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'fits', 'highlights': 'fits'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'highest', 'highlights': 'highest'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'very', 'highlights': 'very'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'my', 'highlights': 'my'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'bought', 'highlights': 'bought'},
#  {'story': 'yes ', 'highlights': 'yes '},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'my', 'highlights': 'my'},
#  {'story': 'too', 'highlights': 'too'},
#  {'story': 'as', 'highlights': 'as'},
#  {'story': 'ordered', 'highlights': 'ordered'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'very', 'highlights': 'very'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'let', 'highlights': 'let'},
#  {'story': 'fantastic ', 'highlights': 'fantastic '},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'nice', 'highlights': 'nice'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'solid', 'highlights': 'solid'},
#  {'story': 'modular', 'highlights': 'modular'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'my', 'highlights': 'my'},
#  {'story': 'we', 'highlights': 'we'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'seagate', 'highlights': 'seagate'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'why', 'highlights': 'why'},
#  {'story': '     what', 'highlights': '     what'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'not', 'highlights': 'not'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'comes', 'highlights': 'comes'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'we', 'highlights': 'we'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'no', 'highlights': 'no'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'every', 'highlights': 'every'},
#  {'story': 'a', 'highlights': 'a'},
#  {'story': 'how', 'highlights': 'how'},
#  {'story': 'i ve', 'highlights': 'i ve'},
#  {'story': 'a', 'highlights': 'a'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'purchased', 'highlights': 'purchased'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'shipped', 'highlights': 'shipped'},
#  {'story': 'just', 'highlights': 'just'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'replaced', 'highlights': 'replaced'},
#  {'story': 'bought', 'highlights': 'bought'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'very', 'highlights': 'very'},
#  {'story': 'great', 'highlights': 'great'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'wow ', 'highlights': 'wow '},
#  {'story': 'most', 'highlights': 'most'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i m', 'highlights': 'i m'},
#  {'story': 'ok ', 'highlights': 'ok '},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'amazing', 'highlights': 'amazing'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'if', 'highlights': 'if'},
#  {'story': 'not', 'highlights': 'not'},
#  {'story': 'small ', 'highlights': 'small '},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'my', 'highlights': 'my'},
#  {'story': 'excellent', 'highlights': 'excellent'},
#  {'story': 'very', 'highlights': 'very'},
#  {'story': 'i ve', 'highlights': 'i ve'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'it s', 'highlights': 'it s'},
#  {'story': 'first', 'highlights': 'first'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'let', 'highlights': 'let'},
#  {'story': 'not', 'highlights': 'not'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'could not get', 'highlights': 'could not get'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'pros ', 'highlights': 'pros '},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'simply', 'highlights': 'simply'},
#  {'story': 'been', 'highlights': 'been'},
#  {'story': 'my', 'highlights': 'my'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'at', 'highlights': 'at'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': '  ', 'highlights': '  '},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'first', 'highlights': 'first'},
#  {'story': 'got', 'highlights': 'got'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'for', 'highlights': 'for'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'we', 'highlights': 'we'},
#  {'story': 'over', 'highlights': 'over'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'for', 'highlights': 'for'},
#  {'story': 'there s', 'highlights': 'there s'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'its', 'highlights': 'its'},
#  {'story': 'i m', 'highlights': 'i m'},
#  {'story': 'my', 'highlights': 'my'},
#  {'story': 'order', 'highlights': 'order'},
#  {'story': 'just', 'highlights': 'just'},
#  {'story': 'does', 'highlights': 'does'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'seriously', 'highlights': 'seriously'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'pro ', 'highlights': 'pro '},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'so', 'highlights': 'so'},
#  {'story': 'well ', 'highlights': 'well '},
#  {'story': 'if', 'highlights': 'if'},
#  {'story': 'most', 'highlights': 'most'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'our', 'highlights': 'our'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'very', 'highlights': 'very'},
#  {'story': 'recommended', 'highlights': 'recommended'},
#  {'story': 'excellent', 'highlights': 'excellent'},
#  {'story': 'they', 'highlights': 'they'},
#  {'story': 'just', 'highlights': 'just'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'stay', 'highlights': 'stay'},
#  {'story': 'as', 'highlights': 'as'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'bought', 'highlights': 'bought'},
#  {'story': 'wasn t', 'highlights': 'wasn t'},
#  {'story': 'ok', 'highlights': 'ok'},
#  {'story': 'speeds', 'highlights': 'speeds'},
#  {'story': 'very', 'highlights': 'very'},
#  {'story': 'great', 'highlights': 'great'},
#  {'story': 'charged', 'highlights': 'charged'},
#  {'story': 'just', 'highlights': 'just'},
#  {'story': 'i ve', 'highlights': 'i ve'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'works', 'highlights': 'works'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'my', 'highlights': 'my'},
#  {'story': 'nothing', 'highlights': 'nothing'},
#  {'story': 'there', 'highlights': 'there'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'what', 'highlights': 'what'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'delivered', 'highlights': 'delivered'},
#  {'story': 'price', 'highlights': 'price'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'these', 'highlights': 'these'},
#  {'story': 'if', 'highlights': 'if'},
#  {'story': 'it', 'highlights': 'it'},
#  {'story': 'we', 'highlights': 'we'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'this', 'highlights': 'this'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'pretty', 'highlights': 'pretty'},
#  {'story': 'compre', 'highlights': 'compre'},
#  {'story': 'i', 'highlights': 'i'},
#  {'story': 'which', 'highlights': 'which'},
#  {'story': 'the', 'highlights': 'the'},
#  {'story': 'bought', 'highlights': 'bought'},
#  {'story': 'my', 'highlights': 'my'},
#  ...]

# %% [markdown]
# input_texts = []
# target_texts = []
# input_characters = set()
# target_characters = set()
# for story in stories:
#     input_text = story['story']
#     for highlight in story['highlights']:
#         target_text = highlight
#         target_text = '\t' + target_text + '\n'
#         input_texts.append(input_text)
#         target_texts.append(target_text)
#         for char in input_text:
#             if char not in input_characters:
#                 input_characters.add(char)
#                 for char in target_text:
#                     if char not in target_characters:
#                         target_characters.add(char)
#                         input_characters = sorted(list(input_characters))
#                         target_characters = sorted(list(target_characters))
#                         num_encoder_tokens = len(input_characters)
#                         num_decoder_tokens = len(target_characters)
#                         max_encoder_seq_length = max([len(txt) for txt in input_texts])
#                         max_decoder_seq_length = max([len(txt) for txt in target_texts])
#                         print('Number of samples:', len(input_texts))
#                         print('Number of unique input tokens:', num_encoder_tokens)
#                         print('Number of unique output tokens:', num_decoder_tokens)
#                         print('Max sequence length for inputs:', max_encoder_seq_length)
#                         print('Max sequence length for outputs:', max_decoder_seq_length)

# %%
input_texts = []
target_texts = []
input_characters = []
target_characters = []
for story in stories:
    input_text = story['story']
    for highlight in story['highlights']:
        target_text = highlight# We use "tab" as the "start sequence" character# for the targets, and "\n" as "end sequence" character.
        target_text = '\t' + target_text + '\n'
        input_texts.append(input_text)
        target_texts.append(target_text)
        for char in input_text:
            if char not in input_characters:
                input_characters.append(char)
                for char in target_text:
                    if char not in target_characters:
                        target_characters.append(char)
                        input_characters = sorted(list(input_characters))
                        target_characters = sorted(list(target_characters))
                        num_encoder_tokens = len(input_characters)
                        num_decoder_tokens = len(target_characters)
                        max_encoder_seq_length = max([len(txt) for txt in input_texts])
                        max_decoder_seq_length = max([len(txt) for txt in target_texts])
print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 13067
# Number of unique input tokens: 34
# Number of unique output tokens: 15
# Max sequence length for inputs: 16
# Max sequence length for outputs: 3

# %%
def define_models(n_input, n_output, n_units):
    # define training encoder
    model=[]
    encoder_inputs = Input(shape=(None, n_input))
    encoder = LSTM(n_units, return_state=True)
    encoder_outputs, state_h, state_c = encoder(encoder_inputs)
    encoder_states = [state_h, state_c]
    # define training decoder
    decoder_inputs = Input(shape=(None, n_output))
    decoder_lstm = LSTM(n_units, return_sequences=True, return_state=True)
    decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
    decoder_dense = Dense(n_output, activation='softmax')
    decoder_outputs = decoder_dense(decoder_outputs)
    model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
    # define inference encoder
    encoder_model = Model(encoder_inputs, encoder_states)
    # define inference decoder
    decoder_state_input_h = Input(shape=(n_units,))
    decoder_state_input_c = Input(shape=(n_units,))
    decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
    decoder_outputs, state_h, state_c = decoder_lstm(decoder_inputs,  initial_state=decoder_states_inputs)
    decoder_states = [state_h, state_c]
    decoder_outputs = decoder_dense(decoder_outputs)
    decoder_model = Model([decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states)
    # return all models
    return model, encoder_model, decoder_model

# %%
# Run training
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,batch_size=batch_size,epochs=epochs,validation_split=0.2)
# Save model
model.save('C:\\Users\\Ashok\\Desktop\\GL\\Text_Mining\\Topic modelling\\model2.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-b5317d787172> in <module>
#       1 # Run training
# ----> 2 model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
#       3 model.fit([encoder_input_data, decoder_input_data], decoder_target_data,batch_size=batch_size,epochs=epochs,validation_split=0.2)
#       4 # Save model
#       5 model.save('C:\\Users\\Ashok\\Desktop\\GL\\Text_Mining\\Topic modelling\\model2.h5')
#
# NameError: name 'model' is not defined

# %%
# generate target given source sequence
def predict_sequence(infenc, infdec, source, n_steps, cardinality):
    # encode
    state = infenc.predict(source)
    # start of sequence input
    target_seq = array([0.0 for _ in range(cardinality)]).reshape(1, 1, cardinality)
    # collect predictions
    output = list()
    for t in range(n_steps):
        # predict next char
        yhat, h, c = infdec.predict([target_seq] + state)
        # store prediction
        output.append(yhat[0,0,:])
        # update state
        state = [h, c]
        # update target sequence
        target_seq = yhat
    return array(output)
